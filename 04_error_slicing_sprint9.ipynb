# %% [markdown]
# # Sprint 9 - Error slicing
# Este notebook documenta el análisis de slices problemáticos y reproduce el script `src/run_sprint9_error_slicing.py`.

# %%
# Ejecutar desde la raíz del repositorio
# !python src/run_sprint9_error_slicing.py

# %% [markdown]
# Ver resultados en `results/slice_metrics_problematic_sprint9.csv` y reporte en `docs/sprint9_error_slicing_report.md`.
