# %% [markdown]
# # Sprint 6 - Experimentos A/B NOC
# Notebook de apoyo para explicar el flujo de datos, la línea base y las variantes A/B.

# %%
import csv, json
from pathlib import Path
BASE = Path('..')
summary = json.loads((BASE/'data/processed/dataset_summary_sprint6.json').read_text(encoding='utf-8'))
summary

# %% [markdown]
# ## Criterio de validación
# Se usa split temporal 80/20 para evitar que eventos futuros entrenen el modelo que predice eventos recientes.

# %%
# Para reproducir los experimentos desde el notebook:
# %run ../src/train_sprint6_ab.py

# %% [markdown]
# ## Resultados
# Revisar `../results/metrics_ab_sprint6.csv` y `../results/pr_curve_sprint6.png`.
