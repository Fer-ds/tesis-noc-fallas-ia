# %% [markdown]
# # Sprint 7 HPO Random/Bayes
# Notebook resumen para revisar logs, top-k y config ganadora.

# %%
import pandas as pd, json
runs = pd.read_csv('../logs/hpo_runs_sprint7.csv')
topk = pd.read_csv('../results/hpo_topk_sprint7.csv')
topk.head(10)

# %%
with open('../artifacts/best_config_sprint7_hpo.json', encoding='utf-8') as f:
    best = json.load(f)
best

# %% [markdown]
# ![Evolución HPO](../results/fig_hpo_evolution_sprint7.png)
